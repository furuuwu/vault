# %%
# %pip install pymysql pandas openpyxl sqlalchemy
# Out:
# Requirement already satisfied: pymysql in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: pandas in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: openpyxl in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: sqlalchemy in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (2.0.36)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

def ingest_data(file_path: str, db_url: str, db_port, db_name: str, db_user: str, db_password: str):
    # Load the Excel file
    df_dict = pd.read_excel(file_path, sheet_name=None)

    # Dictionary to store DataFrames with their names
    dfs_with_names = {
        'orders': {'df': df_dict['orders'], 'df_name': 'orders'},
        'transport': {'df': df_dict['transport'], 'df_name': 'transport'},
        'payments': {'df': df_dict['payments'], 'df_name': 'payments'},
        'client_contacts': {'df': df_dict['client_contacts'], 'df_name': 'client_contacts'},
        'client_details': {'df': df_dict['client_details'], 'df_name': 'client_details'},
        'client_discounts': {'df': df_dict['client_discounts'], 'df_name': 'client_discounts'}
    }

    # Loop through each DataFrame and apply appropriate transformations
    for key, value in dfs_with_names.items():
        df_name = key
        print(f'df_name: {df_name}')

        if df_name == 'orders':
            value['df'] = value['df'].astype({
                'order_id': 'str', 
                'customer_id': 'str',
                'product': 'str',
                'quantity': 'str'
            })
            value['df']['order_date'] = value['df']['order_date'].dt.strftime('%Y-%m-%d')
        elif df_name == 'payments':
            value['df'] = value['df'].astype({
                'order_id': 'int', 
                'transaction_id': 'str',
                'unit_price': 'float64',
                'total_amount_before_discount': 'float64',
                'payment_status': 'str',
                'payment_type': 'str',
            })
        elif df_name == 'transport':
            value['df'] = value['df'].astype({
                'shipping_id': 'str', 
                'order_id': 'str',
                'delivery_type': 'str',
                'shipping_type': 'str'
            })
            value['df']['order_date'] = value['df']['order_date'].dt.strftime('%Y-%m-%d')
            value['df']['ship_date'] = value['df']['ship_date'].dt.strftime('%Y-%m-%d')
            value['df']['delivery_date'] = value['df']['delivery_date'].dt.strftime('%Y-%m-%d')
        elif df_name == 'client_contacts':
            value['df'] = value['df'].astype({
                'customer_id': 'str', 
                'email': 'str',
                'phone_number': 'str',
                'preference_contact_method': 'str'
            })
        elif df_name == 'client_details':
            value['df'] = value['df'].astype({
                'address_id': 'str', 
                'customer_id': 'str',
                'first_name': 'str',
                'last_name': 'str',
                'city': 'str'
            })
        elif df_name == 'client_discounts':
            value['df'] = value['df'].astype({
                'customer_id': 'str', 
                'client_segments': 'str',
                'loyal_member': 'str',
                'client_segment_discount': 'str',
                'loyal_member_discount': 'str'
            })

        # Create SQLAlchemy engine with username, password, and database
        engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_url}:{db_port}/{db_name}')

        # Upload the DataFrame to MySQL
        value['df'].to_sql(df_name, con=engine, if_exists='replace', index=False)
        print(f"{df_name} data uploaded successfully!")

# Example usage:
file_path = 'data_academia_v1.xlsx'
# db_url = '172.22.0.1'  # Replace with your database IP and port
db_url = '172.18.0.1'
db_port = 3306
db_name = 'cap_academy'
db_user = 'root'  # Replace with your database username
db_password = 'rootpassword'  # Replace with your database password

ingest_data(file_path, db_url,db_port, db_name, db_user, db_password)
# Out:
# df_name: orders
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:621, in DefaultDialect.connect(self, *cargs, **cparams)
#     619 def connect(self, *cargs, **cparams):
#     620     # inherits the docstring from interfaces.Dialect.connect
# --> 621     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     360 else:
# --> 361     self.connect()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:669, in Connection.connect(self, sock)
#     668 self._get_server_information()
# --> 669 self._request_authentication()
#     671 # Send "SET NAMES" query on init for:
#     672 # - Ensure charaset (and collation) is set to the server.
#     673 #   - collation_id in handshake packet may be ignored.
#    (...)
#     682 # - https://github.com/wagtail/wagtail/issues/9477
#     683 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:957, in Connection._request_authentication(self)
#     956 self.write_packet(data)
# --> 957 auth_packet = self._read_packet()
#     959 # if authentication method isn't accepted the first byte
#     960 # will have the octet 254
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'cap_academy'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 90
#      87 db_user = 'root'  # Replace with your database username
#      88 db_password = 'rootpassword'  # Replace with your database password
# ---> 90 ingest_data(file_path, db_url,db_port, db_name, db_user, db_password)
#
# Cell In[6], line 78, in ingest_data(file_path, db_url, db_port, db_name, db_user, db_password)
#      75 engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_url}:{db_port}/{db_name}')
#      77 # Upload the DataFrame to MySQL
# ---> 78 value['df'].to_sql(df_name, con=engine, if_exists='replace', index=False)
#      79 print(f"{df_name} data uploaded successfully!")
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pandas/io/sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pandas/io/sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pandas/io/sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3278, in Engine.connect(self)
#    3255 def connect(self) -> Connection:
#    3256     """Return a new :class:`_engine.Connection` object.
#    3257
#    3258     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3275
#    3276     """
# -> 3278     return self._connection_cls(self)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2442, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2440 elif should_wrap:
#    2441     assert sqlalchemy_exception is not None
# -> 2442     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2443 else:
#    2444     assert exc_info[1] is not None
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3280 def raw_connection(self) -> PoolProxiedConnection:
#    3281     """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283     The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301     """
# -> 3302     return self.pool.connect()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:621, in DefaultDialect.connect(self, *cargs, **cparams)
#     619 def connect(self, *cargs, **cparams):
#     620     # inherits the docstring from interfaces.Dialect.connect
# --> 621     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:669, in Connection.connect(self, sock)
#     666 self._next_seq_id = 0
#     668 self._get_server_information()
# --> 669 self._request_authentication()
#     671 # Send "SET NAMES" query on init for:
#     672 # - Ensure charaset (and collation) is set to the server.
#     673 #   - collation_id in handshake packet may be ignored.
#    (...)
#     682 # - https://github.com/wagtail/wagtail/issues/9477
#     683 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     684 self.set_character_set(self.charset, self.collation)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:957, in Connection._request_authentication(self)
#     954     data += _lenenc_int(len(connect_attrs)) + connect_attrs
#     956 self.write_packet(data)
# --> 957 auth_packet = self._read_packet()
#     959 # if authentication method isn't accepted the first byte
#     960 # will have the octet 254
#     961 if auth_packet.is_auth_switch_request():
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File /mnt/c/users/rabreu/OneDrive - Capgemini/Desktop/academy-all-files/week5/16Dec/wsl_version/venv/lib/python3.10/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'cap_academy'")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# exercise16dec

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# Database connection details
db_url = '172.18.0.1'
db_port = 3306
db_name = 'exercise16dec'
db_user = 'root'
db_password = 'rootpassword'

# Create the SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{db_user}:{db_password}@{db_url}:{db_port}/{db_name}")

# Path to the folder containing CSV files
data_folder = './data'

# Iterate through each CSV file and load into the database
for csv_file in os.listdir(data_folder):
    if csv_file.endswith('.csv'):
        # Create table name from the CSV file name
        table_name = os.path.splitext(csv_file)[0]
        
        # Read the CSV file into a DataFrame
        file_path = os.path.join(data_folder, csv_file)
        df = pd.read_csv(file_path)
        
        # Load the DataFrame into the database
        print(f"Loading {csv_file} into table {table_name}...")
        df.to_sql(table_name, engine, if_exists='replace', index=False)
        print(f"Table {table_name} created successfully.")

print("All CSV files have been loaded into the database.")
# Out:
# Loading address.csv into table address...
# Table address created successfully.
# Loading customer.csv into table customer...
# Table customer created successfully.
# Loading film.csv into table film...
# Table film created successfully.
# Loading film_actor.csv into table film_actor...
# Table film_actor created successfully.
# Loading inventory.csv into table inventory...
# Table inventory created successfully.
# Loading payment.csv into table payment...
# Table payment created successfully.
# Loading rental.csv into table rental...
# Table rental created successfully.
# Loading staff.csv into table staff...
# Table staff created successfully.
# Loading store.csv into table store...
# Table store created successfully.
# All CSV files have been loaded into the database.

# %% [markdown]
# dev_data

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# Database connection details
db_url = '172.18.0.1'
db_port = 3306
db_name = 'dev_data'
db_user = 'root'
db_password = 'rootpassword'

# Create the SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{db_user}:{db_password}@{db_url}:{db_port}/{db_name}")

# Path to the folder containing CSV files
data_folder = './data'

# Iterate through each CSV file and load into the database
for csv_file in os.listdir(data_folder):
    if csv_file.endswith('.csv'):
        # Create table name from the CSV file name
        table_name = os.path.splitext(csv_file)[0]
        
        # Read the CSV file into a DataFrame
        file_path = os.path.join(data_folder, csv_file)
        df = pd.read_csv(file_path)
        
        # Load the DataFrame into the database
        print(f"Loading {csv_file} into table {table_name}...")
        df.to_sql(table_name, engine, if_exists='replace', index=False)
        print(f"Table {table_name} created successfully.")

print("All CSV files have been loaded into the database.")
# Out:
# Loading address.csv into table address...
# Table address created successfully.
# Loading customer.csv into table customer...
# Table customer created successfully.
# Loading film.csv into table film...
# Table film created successfully.
# Loading film_actor.csv into table film_actor...
# Table film_actor created successfully.
# Loading inventory.csv into table inventory...
# Table inventory created successfully.
# Loading payment.csv into table payment...
# Table payment created successfully.
# Loading rental.csv into table rental...
# Table rental created successfully.
# Loading staff.csv into table staff...
# Table staff created successfully.
# Loading store.csv into table store...
# Table store created successfully.
# All CSV files have been loaded into the database.
