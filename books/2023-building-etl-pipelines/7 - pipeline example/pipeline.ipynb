# %%
# extract.py

# import relevant modules
import pandas as pd

# extract data
def extract_data(filepath: object) -> pd.DataFrame:
    """
       Simple Extract Function in Python with Error Handling
       :param filepath: str, file path to CSV data
       :output: pandas dataframe, extracted from CSV data
    """
    try:
        # Read the CSV file and store it in a dataframe
        df = pd.read_csv(filepath)

    # Handle exception if any of the files are missing
    except FileNotFoundError as e:
        print(f"Error: {e}")

    # Handle any other exceptions
    except Exception as e:
        print(f"Error: {e}")

    return df

# %%
# transform.py

# import modules
import pandas as pd

# transform data
def transform_data(df: pd.DataFrame) -> pd.DataFrame:
    """
    Cleans and transforms crash data.
    :param df: pandas dataframe, extracted data
    :return: pandas dataframe, transformed data
    """
    
    # Drop duplicate rows
    df = df.drop_duplicates()

    # Convert mixed-type columns (strings & numbers) properly
    mixed_columns = ['crash_date_est_i', 'report_type', 'intersection_related_i',
                     'private_property_i', 'hit_and_run_i', 'photos_taken_i',
                     'statements_taken_i', 'work_zone_i', 'work_zone_type', 
                     'workers_present_i', 'most_severe_injury', 'location']

    for col in mixed_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")  # Convert to float, replacing bad values with NaN

    # Replace missing values in numeric columns with the mean
    df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)

    # Replace missing values in categorical columns with the mode
    for col in df.select_dtypes(include=['object']).columns:
        if not df[col].mode().empty:
            df[col].fillna(df[col].mode()[0], inplace=True)

    # Convert CRASH_DATE to datetime
    if 'CRASH_DATE' in df.columns:
        df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'], errors='coerce')

    # Convert integer-like columns properly
    if 'POSTED_SPEED_LIMIT' in df.columns:
        df['POSTED_SPEED_LIMIT'] = pd.to_numeric(df['POSTED_SPEED_LIMIT'], errors='coerce').astype('Int32')
    
    # convert every columns name to uppercase
    df.columns = df.columns.str.upper()

    return df

# %%
# load.py

# import relevant modules
import psycopg2

# establish connection to the Postgresql database
conn = psycopg2.connect(
    database="chicago_dmv",
    user="myuser",
    password="mypassword",
    host="localhost",
    port="5432"
)

# create a cursor object for running SQL queries
cur = conn.cursor()
print('successful creation of cursor object.')


# suggested continued learning: this function can be modified to be fully dynamic
def load_data(df: object, postgre_table: object, postgre_schema: object) -> object:
    """
    Load transformed data into respective PostgreSQL Table
    :param df: DataFrame with the data to insert
    :param postgre_table: The name of the target table
    :param postgre_schema: The schema in which the table resides
    :return: cursor object
    """
    insert_query = f"INSERT INTO {postgre_table} {postgre_schema};"

    for index, row in df.iterrows():
        if postgre_table == 'chicago_dmv.Crash':

            """
            crash_insert_PSQL: '''(CRASH_UNIT_ID,
                      CRASH_ID,
                      PERSON_ID,
                      VEHICLE_ID,
                      NUM_UNITS,
                      TOTAL_INJURIES)
                      VALUES (%s, %s, %s, %s, %s, %s)'''
            
            Columns in crashes_transformed_df: Index(['CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE_EST_I', 'CRASH_DATE',
                'POSTED_SPEED_LIMIT', 'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION',
                'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE',
                'TRAFFICWAY_TYPE', 'LANE_CNT', 'ALIGNMENT', 'ROADWAY_SURFACE_COND',
                'ROAD_DEFECT', 'REPORT_TYPE', 'CRASH_TYPE', 'INTERSECTION_RELATED_I',
                'PRIVATE_PROPERTY_I', 'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
                'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO',
                'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE',
                'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I',
                'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'NUM_UNITS',
                'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
                'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
                'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
                'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH',
                'LATITUDE', 'LONGITUDE', 'LOCATION'],
                dtype='object')
            """
            """
            insert_values = (row['CRASH_RECORD_ID'],
                             # clearly, i was supposed to merge this table with the other two to get this data
                             # but it doesn't matter anyway, i'll just skip
                             # row['CRASH_ID'],
                             # row['PERSON_ID'],
                             # row['VEHICLE_ID'],
                             row['NUM_UNITS'],
                             row['INJURIES_TOTAL'])
            """
            insert_values = (
                row.get('CRASH_RECORD_ID', None), 
                None, 
                None, 
                None, 
                row.get('NUM_UNITS', None), 
                row.get('TOTAL_INJURIES', None)
            )

        elif postgre_table == 'chicago_dmv.Vehicle':
            """
            vehicle_insert_PSQL: '''(CRASH_UNIT_ID,
                        CRASH_ID,
                        CRASH_DATE,
                        VEHICLE_ID,
                        VEHICLE_MAKE,
                        VEHICLE_MODEL,
                        VEHICLE_YEAR,
                        VEHICLE_TYPE)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s)'''
            
            Columns in vehicles_transformed_df: Index(['CRASH_UNIT_ID', 'CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE', 'UNIT_NO',
                'UNIT_TYPE', 'NUM_PASSENGERS', 'VEHICLE_ID', 'CMRC_VEH_I', 'MAKE',
                'MODEL', 'LIC_PLATE_STATE', 'VEHICLE_YEAR', 'VEHICLE_DEFECT',
                'VEHICLE_TYPE', 'VEHICLE_USE', 'TRAVEL_DIRECTION', 'MANEUVER',
                'TOWED_I', 'FIRE_I', 'OCCUPANT_CNT', 'EXCEED_SPEED_LIMIT_I', 'TOWED_BY',
                'TOWED_TO', 'AREA_00_I', 'AREA_01_I', 'AREA_02_I', 'AREA_03_I',
                'AREA_04_I', 'AREA_05_I', 'AREA_06_I', 'AREA_07_I', 'AREA_08_I',
                'AREA_09_I', 'AREA_10_I', 'AREA_11_I', 'AREA_12_I', 'AREA_99_I',
                'FIRST_CONTACT_POINT', 'CMV_ID', 'USDOT_NO', 'CCMC_NO', 'ILCC_NO',
                'COMMERCIAL_SRC', 'GVWR', 'CARRIER_NAME', 'CARRIER_STATE',
                'CARRIER_CITY', 'HAZMAT_PLACARDS_I', 'HAZMAT_NAME', 'UN_NO',
                'HAZMAT_PRESENT_I', 'HAZMAT_REPORT_I', 'HAZMAT_REPORT_NO',
                'MCS_REPORT_I', 'MCS_REPORT_NO', 'HAZMAT_VIO_CAUSE_CRASH_I',
                'MCS_VIO_CAUSE_CRASH_I', 'IDOT_PERMIT_NO', 'WIDE_LOAD_I',
                'TRAILER1_WIDTH', 'TRAILER2_WIDTH', 'TRAILER1_LENGTH',
                'TRAILER2_LENGTH', 'TOTAL_VEHICLE_LENGTH', 'AXLE_CNT', 'VEHICLE_CONFIG',
                'CARGO_BODY_TYPE', 'LOAD_TYPE', 'HAZMAT_OUT_OF_SERVICE_I',
                'MCS_OUT_OF_SERVICE_I', 'HAZMAT_CLASS'],
                dtype='object')
            """
            insert_values = (row['CRASH_UNIT_ID'],
                             row['CRASH_RECORD_ID'],  # Corresponds to CRASH_ID in the table
                             row['CRASH_DATE'],
                             row['VEHICLE_ID'],
                             row['MAKE'],
                             row['MODEL'],
                             row['VEHICLE_YEAR'],
                             row['VEHICLE_TYPE'])
        elif postgre_table == 'chicago_dmv.Person':

            """
            person_insert_PSQL: '''(PERSON_ID,
                        CRASH_ID,
                        CRASH_DATE,
                        PERSON_TYPE,
                        VEHICLE_ID,
                        PERSON_SEX,
                        PERSON_AGE)
                        VALUES (%s, %s, %s, %s, %s, %s, %s)'''
            
            Columns in people_transformed_df: Index(['PERSON_ID', 'PERSON_TYPE', 'CRASH_RECORD_ID', 'RD_NO', 'VEHICLE_ID',
                'CRASH_DATE', 'SEAT_NO', 'CITY', 'STATE', 'ZIPCODE', 'SEX', 'AGE',
                'DRIVERS_LICENSE_STATE', 'DRIVERS_LICENSE_CLASS', 'SAFETY_EQUIPMENT',
                'AIRBAG_DEPLOYED', 'EJECTION', 'INJURY_CLASSIFICATION', 'HOSPITAL',
                'EMS_AGENCY', 'EMS_RUN_NO', 'DRIVER_ACTION', 'DRIVER_VISION',
                'PHYSICAL_CONDITION', 'PEDPEDAL_ACTION', 'PEDPEDAL_VISIBILITY',
                'PEDPEDAL_LOCATION', 'BAC_RESULT', 'BAC_RESULT_VALUE',
                'CELL_PHONE_USE'],
                dtype='object')
            """
            insert_values = (row['PERSON_ID'],
                             row['CRASH_RECORD_ID'],
                             row['CRASH_DATE'],
                             row['PERSON_TYPE'],
                             row['VEHICLE_ID'],
                             row['SEX'],
                             row['AGE'])
        else:
            raise ValueError(f'Postgre Data Table {postgre_table} does not exist in this pipeline.')

        print(f"Insert query: {insert_query}")
        print(f"Insert values: {insert_values}")
        
        # Execute insert query
        cur.execute(insert_query, insert_values)

    # Commit changes
    conn.commit()


def close_conn(cur):
    """
    Closing Postgre connection
    :param cur: posgre cursor object
    :return: none
    """

    # Close the cursor and database connection
    cur.close()
    conn.close()
    print('successful closing of cursor object.')
# Out:
# successful creation of cursor object.

# %%
# pipeline.py

import yaml

# import pipeline configuration
with open('config.yaml', 'r') as file:
    config_data = yaml.safe_load(file)

def run_pipeline():
    # Step 1: Extract data
    crashes_df = extract_data(config_data['crash_filepath'])
    vehicle_df = extract_data(config_data['vehicle_filepath'])
    people_df = extract_data(config_data['people_filepath'])

    # print("crashes_df:\n", crashes_df.dtypes, "\n"*2)
    # print("vehicle_df:\n", vehicle_df.dtypes, "\n"*2)
    # print("people_df:\n", crashes_df.dtypes, "\n"*2)

    # for col in crashes_df.columns:
    #     types = crashes_df[col].apply(type).value_counts()
    #     print(f"Column: {col}\n{types}\n")

    # Step 2: Transform data
    crashes_transformed_df = transform_data(crashes_df)
    vehicle_transformed_df = transform_data(vehicle_df)
    people_transformed_df = transform_data(people_df)

    # print("Columns in crashes_transformed_df:", crashes_transformed_df.columns)
    # print("Columns in vehicles_transformed_df:", vehicle_transformed_df.columns)
    # print("Columns in people_transformed_df:", people_transformed_df.columns)


    # Step 3: Load data
    load_data(df=crashes_transformed_df,
                   postgre_table=config_data['crash_table_PSQL'],
                   postgre_schema=config_data['crash_insert_PSQL'])
    load_data(df=vehicle_transformed_df,
                   postgre_table=config_data['vehicle_table_PSQL'],
                   postgre_schema=config_data['vehicle_insert_PSQL'])
    load_data(df=people_transformed_df,
                   postgre_table=config_data['person_table_PSQL'],
                   postgre_schema=config_data['person_insert_PSQL'])


if __name__ == "__main__":
    run_pipeline()
# Out:
# /tmp/ipykernel_51841/4176932845.py:33: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# /tmp/ipykernel_51841/4176932845.py:33: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# /tmp/ipykernel_51841/4176932845.py:33: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('530411c8611eb0ccb9b25f16b2955cd21761fa1928dcaa71279438be032526d11c08ca75075f176d2dc0085665b171fd57eca2c7cf88221d1191d351867bec81', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('305b06235b250aa0029c07313c84f969f4bc13c1cc371592780886815ca51411acb80530c99edd0cd57329d1e808ca56923fb2d4a8ba93bd7d0b272eda9d769f', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('444221c2a9bc82fc4f301062ab22b482d7d661cf88fcdf3b7b7e04e3675673f651dc99513069ca0ff83fc0bd852790324463419e52ba713a25703c94d15a156b', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4603435fbb4ef5d45c0d805c3e9aa5558a311a140a737e37aa56d4f70ea0161f8f2e187270d33f36070c6a1b0f0c26401d0f0ad8b3f9dae797f8041f754d6297', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('db62bb4534d0dae57112ea3ff8d50193784aaa732ed58d1fe2f7ccb826798a0e6c56cf119a5102e696b79aa081ef0af9f96ba1779d17bc7fcc258675d53ae540', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('7be2d128e14efdcb70fdbf27dbe8fd18f31a045118f2b03095d02cc94e1d425027841c74d144734dc8ed2e59b29bb8a351ef18db34649ca75dff5e009bc5a746', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('b21c3c048ac319f0fca67804ab0fce0149c97d11a850fff5aba1e5d123ae0cbaec29799c1bc7e289e70303e2167606867a2e888220a341464d5d2818e8745b9f', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('ff9ed4054cd9f4b2908d1e1ef79a4e70d752a0ba7907b22b071276601c1b2b983b557104350e906a691182b8c07f753462a5d72d906d0f7d4ca74ed0d8bbe387', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('0ff41d1ad3fb1e9bba0015c72222f5569df3b1254ce9d09e8aaf2414f408e31fc293b445df4c28a3e3cccf0fc89adc33e08720ed706c27a110c92ba5854a77a4', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('77431b38762c7d632f83881886b3a1c94a52f6cb17ad6eedfee76629d0f68ad6def7faaa8fa348e4c706996b4c45476a864223b5c0e7e76cfff2b41ba4d527a4', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('1c34763adabf56d36bdf33806e026a5f6794b1e7a3ca5c43ca4d7ef8d9bd13c70989498247ef0428df9ee1f83f66863bd254e5042510c7c462ff2fe4812468ac', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d190dd973dea076b750308dff1272f56fa724e93d8a54cb16ee56cbb070522c4ca87ec75ffc9a8c1c10971aa391d872096c92bee4351fead8e0b01a6caada0e7', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('7e1a75d221f1f538b80def6a7c5f9f522a3309108eb18f9d0cb43e7c0eaa00b826faa099391ab318e4988c3b7ca5670033be16f0d43c080471efd354b8de2f51', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('1e45565493f63101bf704046d6ecfec55f57c832334671cf7043df50f1222915174a4053d8b6b4320262dceb519dd5720f08ae7b2a4fa2b4a668c1fc6319f2a8', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('06961f67044ff197083bc79024a5aaab4ebbe7c404d70d08317ff06c1f5a20bfa80d9d52cf7fb6e3c492d9980a8852196589523eefea991e0c6fb8ee7b22b6df', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('9c863403d810d021c785ee768f4ceebdace75f5b4362125cdf5ab4878354be2fdd87dad89e20d7cc9eae3d7c87fe1663e574fa94e83f1c2aa202d086d9e6382e', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('05a62c985bffdfb91b5fc5250b8cbb4cb0a0647bb06387151c752e49874a403fd5d864f4f2549404b19aa5f49c8f1b50f934fccf990aba764670588a215d8deb', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('0ccaf8fc934aca647afd767054141022c18b74d15c78a67c7477e1885c4f2b87d180001ace77fe993a909a5c3464dc9ff14873226e5ef0fa4a8bbcf3f3a1e9f6', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('62acc5daf51d9f8af2f3e70098904e0a241fdd024b463725e54f379313b888d187472054e2414c5868c894280606c81a358b099b9d6bcd747136f83465f6bf13', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('a2fc08d7c5bbd1ef56f6dd1023c07951985f35614b4d9c7a91ba707a9c4de33cba1a058342fe8967b7d18d588be888e0ea40cebafe01729203744483dbbaa436', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f7999cfcb19a2e2fa3ac1a0c374b58a18474fbec81464fd37a1aa86ca45a99af988f96c6049801d439accb95867c1882cb57f2713054dd36c894cdd71e6daf74', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d6b30daf6d409e36503555e11c38be88be9c6a219133869945988acc6034ae514c3c907772673859fefe83127de044baf9c6b119ff915e2a70b992b6105e8d26', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d6023c5fbeb45276b6885272212a98dbd1d1efaf4ab470ef15b938029ebd992fac862800cfd091a9979ced79893c1bcbbba264a5414fe8db1d486baa951738eb', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d5a794a66ae75be7eef84fe0d96e68164db1a205522e37ba13d93bbc3d22477645d9f3ce0bb71ffd73968960bd9d73cd0ad0698b7aa9f3109b8c08383ba1d6d9', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f54713d6bd4a2f0c5b1237713c35202c186b3008f9a720a624c832b679c559c9540933874fc521aefc476da7d516da28e8503e2a3f2bfe1fe1745adbf6849756', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d3394aad2f75a822b92a1bb385d43e6abc335bf9002ec01f02263e63742e2db169e40a3fcd7f89d6ed595cbb28d0ad61cbda47841fd54db194a39b8cd256f376', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4056ae957c7e293f83b458945e7e32c50f635ea49a12723b6a2d2a985b45190d1aa55e1f2c405d0b5776cd66af0495999d8aca704e96f947577f48face824f9e', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d9cf9c4a6b7263e48e612f6d2d041080efe9af446ff378ef33f1ca8ccbc0b541168f139f331ee9fdffc87c868a52efdac55c53e33857f41538c1486596ac9b63', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('1f4e04f1aa0e46ea1ecba896923870ef2b2e4eed7f73da74bdd87ad40500a7a95b9c9a6b22b2189c2713210f6fc8fa29d3ff0c18783981ac916d54bd58744fc7', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('9d36131852925b709f35a2eef49fc0f209a6e38ac912ce77b600ddbb246a39419f5f63715fde3e57b0ae1970bf69353de2aaf381be0f153ed51e7c6d32adc9fd', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d12d50f24317618fc9a0b6ea8bea73cc8caa5040d73d006e4234bd9efca3fb9b0977fb0894f2d74ea216cc9346ee26ba0ccdf0fc169147e1ca5f14c9ec8e8651', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('b2a883f0294e88a60533a76ac5b986dc68e66908adbbd799f7d45315fff65d1ee7776e3f6e748e6e0ad2b07b0801d517a1f212090fe83da69908b0588d25a502', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('bfb452d8bde44f56587b494a3291dae40a47c5c64eb3d2d9ae0f22dfd0b272a2e4c88039ed18ad86f5586a08b27b2ff55e2a33803044602458d555ab6bc8dc5d', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('7d3a0bd116bb0c1b554f0c4772e6a04790b724b858e50c3cb2270b70ee19a8995322f307e7a275a75d2b144cc145ac767f9728e1617fdb3e1078c93a9e9a7786', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f12b14f8eff817567130b48a52a407a4d9c5cb3a437c3eb251af0f1d76146038871da3e0011283c8a1aadb4759882a35010c5de7de0b269ab796ad6061d250d9', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('aa49cf01197f55ecd6d0413097c107979bb77ff7d757273d8e159b930d36607e03e781eea55ba6db558a168c329a04aa4cae6bc5c6f6272229304067136a50cb', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('7a0e671d95d3dec797b64b50241912247ec3c258de346d96bfd5f18db9ae0f3e99d37d088ef5e814b2137a4c5e808acb33466e2293054fe02aa90ffbd665a7ff', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('5113a38824469f53baf91a3a797c7c007b24065d592abd0cd8c62f91557ee32e5c06dddbe516479687c27228b6935695446ca0c6e27c595b70f8fb67b5297633', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('3e639edea4565457418b61b5ed70169e2d3a513b4bbcc16343e8cb6e8f95e6a91296e23137c65b0fbc097fbc27b1d3fa6dbde253673ade73a598de5ba24bf7da', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('5a2501721ec3424dbb913011e7b0d54743583e790277134d53bec5297696430e709c3399c1ab1ee46b91d17f9ed8333f33d87e5c711c201fd8eeb0b7c02ee053', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('0ee96e44362f7c3b58e795d81e1507ff968427579526b5aaddc463888438a10f41ef488d70c29f17fc77369dabd4ccf667e1efcdfbd1c7d3315e137eb6f1622b', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4e592de79e9fc053f11795c71c5af0d72cc86e121fa0337eacce2f98787343a2d1e68470a11372a9cc929fbd6726fa248e54ce3fa2d462ee56383414eb83d492', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('bb6a109875ae398cf8cd02a41ea41b09a495c58333d6177d1d8153af28d85e810456bf28b6eb2e5cff6011e00262ccc67dc844e98dec621a7670a978f294ab52', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('ec2a93d4f327b8bb35b3866cfb4af4634e6d31b722cec95e88060d74f396a0da3585d8b8191f4d0f565702981d96445087c5dc2ea3e4015316750f28eba155db', None, None, None, 5, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('33199001bec1395120db68044f3354bd769f5396f04aba87168dd2c1ea218c395a2791d0842dfca9cf56fd8e8e5499661d5fcfff74cbbd86eed828d5b9cd1944', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('8db693307e1a3c9cbb52d5e4f84fb1124c124c635d03c45786b4b2d651e6ed9b3383dc888c66bc104012ef97e22a0a3ffbfc811c4d5003e1eb740b8fc5ca0618', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('a150853e0070fc365233beaa0fda72a69950b16755ad17fc9d2f07eead716267711e6b9749d6b31e7cea6b7ca9b0b1cbd5c3f27f5c356ee4038ba01d396eccbc', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4563ea35c2d594bcc0d4bc8d35c36f5eb2e6d60322d43a679d66b947e4fe576a26b75480e357c5e8e573628a72b6389901347a97d966fb98f2f17c8a6c4a3ec7', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('89c0634c536ba5736b287ca4c3e41fb5c19b98081e423ac0045fb1d5c0c824cf7b3c12cf952e61d0cbff423c32c574fa519a4a12a4ef6729992ace3610d1ec05', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('ec5a8407e604576d40f94e9352d938e7c4b92e033f969453878f30a38da579d921a9ba56e45b9f6c91bac0d6dbccdac23970a4a159484bf1c41598ebf7ef70be', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('c92f121c0e6a4e85435224b77cb760b185aaf41d14cf44c41e5de340bf04063e9db4e45e277431fbf695df7b73844836bd374ebb419e830b9c0099423fe8e58d', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f09f5e9226bc4260b55fbf913bbefa9485e89e377b5160ed34a1e2f6d8f5df58fc8ea022fc62baa14ee9b9a18db5b4a2e22838687b2f4f715e8cef0fa529b25c', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('67a911c04f922342ca2a160de88405bb729bd1433afa0ada1497dc6e3013f1af3998e5dd36ce79064e493b8461d1119abb931dd35931746c18cc6c766dd663a7', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('e26f26a6b566af66da062d5319f8cac412ba2ac51073155805dcff5efce4c833d3c34b8838190f90692095d03603b8c99ae937ea9ca62d6280a413704a7da02e', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('ec4a5ff5040f9d9ee28bb366c9b82fcac1ae167b2a6fc170bb1165cd3c5c25d562e072911c1145a9645c867cc906c2bc04fd5ed2f3ce132dd1ef864c10d82039', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('07119a29b64a3007eca90578a42d35248c69eff9e10a72b456b493acbbe3443e3a44c2f421f589d29111941f71dd9cdb4755c28ea866c410b57507e58513ca2f', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('68e850d0d251158e8cf29598a80053eec444560e54cc25564b8679f92c71e3372b7636909cf617169dc18c56bf6bc530e295feccf62c40829842e3e3f6ee95fc', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('887d8322b81a1c2fc97cf045054213d1aa6a576b5623b6328bcc5b6f3a4c96f55851a9fb1b9aa76be1a0dacd2b4ce66a7f29ba3ebe3c8bef8dd72e20842c4fb7', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('033d6ccb529acd5761d434d81f7bb18e8e9df85e61751b83db65eb6cd92b3cafeb9ccb7859fc0d87e033d54e39bbbac15a04514404760a1a66b75c161fdcc5a5', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('74a74b138f3327c3b978b365f9c2649f9cb6d3520bdd906f383c7b6eebdc807a52f5f2e5e258d35c1d33870a1335d1311ccf912cffad72d4a30413a4fc41fbef', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('1bd0414458cb79e06a032fec9f428ab5aac00ae80ca64ff2dfaf8d17bd430bfd0ef870740cbb668c391d68c146199cc30397d8a6e2c004b4ff5d89c165291258', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('69891d21a7e6d159d8e302374a3e65d05f65d44824ba8bd93cc83285f9a4b5c66564a52bfe71f1ddf6b4b5af26961da335d066a2214f1a401c50b23df4e33aee', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('19f0e43196a129b434c4649242367d0f8808b049eb6ee454bdec9faac43ea58f716f15ee9bc530ff0b7934452973f528b3b9a3a995f69f397aa946b6da338645', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('181a4321bb2d6492518b87b2d483bef22d8d9f7795e4eaa7b5f82241f3e8923fe5daadcebc53f1f0e1de573e5e1b381d55d9c0279f2132a705ff514aeccbb97e', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('406d64a79914d610f67138a496f2cf1235d4ee507f83bc3a38ce3e243536ae68406cf1392d5a8dc91d94279c4fb9d0e647ad34e6414e2555d9cb17273413d49c', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4484187e6ec361804d1a3b565a35336f87d910d524b3a4b243222dfad41dfd89c7ebd610445a5b93a6b2d8ddf1a37da1d352eceb79e91b9b907208e1c29e297e', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('2b61a56f3d20e2d75fa3c246f06ff22e21063d146711061e7dfc84e3d6ffb03bac65605bdca89d6f8b91d231a6c63ea700acef0ca3877bd2da05fccb50d2260c', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('04762a2b67cdb3a50a9ef077606696cfae98ee59ed0d55f924d2230d991c583c714dc75565a79ef17361ac62d899989e020455f93d59275c310d17564c58f6e2', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('270c709dfd1ff27e206d80d22cf12453d63c4980bd6133e5d6ade3469880b7804add274d709d01cb194d5260f94c97d91b88ad3fa51236aa6ead74f769728706', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('887d557e73c99e702f433fb57229bd7cfcd4e8436ba283c6f1c354c5e0cd2b1468415e9c0adcbad65750236809dbfb481f99149e1713f89e7269d829a773bc23', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('96b2d961a07545ea6663550ea9a406221cca0090a17451489e37341ce82220cace5a635983e8017875309bcb4ba6cdb65d5072aff1273ed74312bee39244d77d', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('49d918a211a9b58ebee032b34de08084f94b3a45f37dd52a0398ace02f5c387425b298512a438c5fffe4a1749dca7615369f2f144d7a24a2073d531c27c231ea', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('b4fcf51d938fdb0ba7842aac5debaf4934bb080712874d6d19211cf107e76cafe6f5b9d8a60f44bbbadddd1c886fbc416393ded182b91c7e17b0aa0d22dd4337', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('76c6a53e9f56c049a9c0630fb81d8b9f7bab5837a04ada0f1fdcb783f38cdcd760782e6f28ae4fad152568af8c805a9093aeba4e8c22e36ed8dc16dcd0b9cf85', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('2028206c24fef84992001017aa35723c9d1dc5d9cf562e715492b065f2c3082e96f8432e9a8360f8aba96d94c23124b9b2a5848781dd2388316fe5ed40e13543', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('dca010d6e89d95a0b78e69a46ed9aaf4b0f37c96900bc0e6bde8ffc53d5d9404df214ff8db9808589e79b265c65cba2f203f1b2229b38d4382052ae428304948', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f1cedcbb7cec3b1465d933e33d71ff173c8b19d7c1989d40bbef3b115d846f074f42a0b27b40682858079456616a4bdda1b08c2d159fca5c7ba05c2dcff3fbd5', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('5705cef67eb6b21767f0f49f1b59b8d233bd7d7839189997dd64801f0fae32afcff36df692da0da65595146550d0413fc3394cffff61648737bcd4dffb33887c', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('0b4af80cd3854ea7936d3874b949e4d30f331f9fa103d472670041fb1f7dd59ac386cec24667cdd4aa759ca72f25ac2c8ab9784ac202a14c6c9f9917ddc4e436', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('070d567ca3496ca7fd2db01b19efbd84760baaa74644827323b9d05a7a8454b62124217d75fe29e6303385f7723954997b6bec6346eb578e60d54dbc533a5983', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('21b31098d5d0c0295e575eed401e7cb9f503f695b390c695c42e87b46642f7e304dd33904ef8bf17cbd739c1829e52883437e4d9d9abfc4deff30112e75f53d1', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('057fbd309e24786cd3cc6fdf444ae09b5c9a96e6a9593b8df3fa8ae5bbc542ee1bfb8c3592ef71a674b74f8773ce017bb7de77ecd43e157f56252e017c03e403', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('5a815e8f2f0fee11c61a20e559932980c48dbcdb7039e689db5d713f715476aa6ebde7081c278803c1fcd491af9474f0066ea0521cfe80ed2d8192d5c0124534', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('8bc14e769ae32599f6343cadd156c2d22f86a2a8f744167730d6dbf02d405f37cee48014d87b863fc0a8b141e3833af9a183900064dd0384c93b5b5f078ecbb7', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('26bae3add7acee99489a757e37a1fe327c52de845a7a13146918990fdcc9b7b11a86eb47bac2e69ecc50eaa7987e8e58cbbbc7d5cd8aaa1a7d14fb351299a851', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('651311702a28adb81709bc1e0e2fb2a13f23fac4dc8686bd559abdb50912eaecb327cc8185f1026cd7f96b30092da05b5c430a06d156d86a18ae8047429afca4', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f441d5dcea88b62f44a3350375e09f840241cbe2b03b4339d946a654d780d803d70ab7ac3372f5dfd15fe4c20804b096eb47d8d300ce1890601f4826efdba04c', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('829f990cb5d2861fa310e4838e63e01bc726449fa23007b1989d43f380a05d9bf594b1d55dbd85e3602567ce56f5a743e112ccb37c45e3aee44c87317519f0d2', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('87ac9b1f0ff7adf2d1e73866cea29aefaca781974117610106f5c90ecdcaaec6190f9c5da1fc770185076d8ed6320d1bdf250362169a20dd2405769cfdc4dfb9', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('fb3be6ee6fa6e655abbf47cbcbd3ad5702c49e96fd632f3db78eced62f0c34666e5e57c79a4c9b18719b5d967017f2a92d6c395d22c1fc42d64174beb49f2ca9', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('16365221cf4132354a3ac453eb5cde37a8eafe2c2825ac0c16463eb3b95bcd9b1c832e2d152c23b68ea960419afc4ed7d588ff96b8a48cad6888f53649bc3dd6', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('0d2ee59ce28bef717715d9552af63bb8ca5de0ab1a073a6d79298dcc94a05c4282f725d11ac3af5006ba881ed2c3d8037b4e8153b211df4ef70e644aebadb20a', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('198e101f51f905de6317d8df3cf019dd65716ee12ab5484860507d9c336ae0ab5f95803dd473a6076eb49a2fa9a6c214157bb30090279e360855343955bdebd1', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('51d9c6c4386b9fddaaadd8681e1cbe62fff5216782fa8c41359e0151d7d261930b827c82750bbe0fc17f64f659ec3adb1bbe85bfaa0b4c1f5c4d216854d19bf8', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('47d1a97d5ec69e0165405bb992123d074ef33dbc15744a9a6ad03d079bd0113e2015f84b455cbf6bc59cb873228749159156b9d8269572b37de03b2b063b62f5', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('20d09ec30238f215edf1b854d4f0cc43e1fe591c2c35842b650b061e1b2b9140737c50d0517abfb5a6d6946e937d9c79bbad68b5463f5a2119731b97cc32a001', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('fe25fa42956a9a38f3925423ec61aeed1dcf10df4f5433d134826818402ed5e5d019cd8ff6bd4459a935a0c5406eaae4dc72b607de77827701b61cf3c481ef8e', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('330e45f9dcdb2f81415fd4a3c8e7220ca0c72188115a80ad78182a1d6e685f32366de17001aeeab7d60bcefbfaa67a4245610b8b0d32b90b52f821a09e316022', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('6fad8c9a800348db33d77104ef7df6350adb469bd68df459283a5e5237574c00b3644bcb06d91f25bd448d2981a8fd7ab35e2e8006348ef0c3fd889c60138a29', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('26ff5334ad2f96acdfc3dab210f2f59d77f387af4b071c9128d096be71cd32baacf670426879c6685bce57ff3e3c2fbc407ee9dddfdf69c651ee6dbe2f40e224', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('83991427f67a99039881775d52ea94bcb67f9c8176ac3fe9a0a24ce8afa69cb6157b69716e426c66b3356a7f68e347c41a7178f9eb94a6106cab3f4df7d24440', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('1a5f6752dbae9d0479bfbbfb3f69b654df9a335851dc56125a9d5a142aca941abb5d94ec9a82d59eff6d0671280524675ed97bf0344a9f3cfa863cd27423cb7c', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d6c9d5c52382e49df3ab10fbe4bae06e2d93ac38a283016915222a525a4b4b03825b2d8021be8cba875b96a58386e132cbcff9c5ca1d34f8b9333b0a5724e8e6', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4e3e4a9d49e7d947e4e37317596705b74b58052eaf1937f9ed2a7f7197f4d6d33cc3b04cbbe4fc15342eb74ccb7764d7702d7f69e095b982a6bc20d50aa0c013', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('75224392c2599d276dc4bfb5091921e08bfc033f084392dfb3cbed734b3f996914c122115dc5f3f09f222981414ab5db1fcb1ec6cb0ff078dda683a2d2adc551', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('6a45a5bcda41d615c47fbfe6fa3cf5b4ceeb189798724ffe5196cade131971587eb4f50d43361f111e8e5dcc7eb40b34d57cce56345c8aee638478b2aa42c8f0', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('b9944f6ef5c3a5c0745fd2578f73c9749e60ec00f38d2e64e2483a7da26becebe0d0eda2112f1a16a3c0fb37ea9338d1ece1af6623bb7a18646c8552a7fc0e5f', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f0d3f241728d2cd757f1d9f6aa4c0722b23f8027ecabb7d518f15b0e3ef9711a6bcadd2dc0772cb915011bc4b04b1c032bed076df45bdf3bbfd5a0659ab19c2e', None, None, None, 5, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('93885d4c6e257e66e5f17f088d82e926465616e05da26aebbe8e35492168c1a9a62d6352a08c1a639f9fdd56abf4262b1cc90e8f43dfffe8b4d6a31efc7ca38f', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('41db92eebe41c11061c8fe056ba7b80f1974320ad20374715e878374dd60353784907bfc8241439647040cab146abac4a608e386c3dd4e46d193ced63e169646', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('e95669b125f131d767918554f5008a3179c604f0678b0ee6107345306833438a2ebd3ca736248b34216e35a82b55ed1fb633beace3d1ef6ef7e26ce8474e6046', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f85d56563b36237d88bbbdce4d1fb2b90d87da084d2f0f8aec3e28792cc9e4c9dd491ef29b681a623810e06a58714d4e339cd712058062304e777e31785d5069', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('629846065f2798a16a8e9091cd17f4acb82f422e3d0b799da2739480fea71db9871779f31c60b7785c6b11426a714d1aefe19fadc6a67b71d88445ff23026b95', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('3d887ae602b85a8be3b9d0e52bb95cd9e868940ac69d9c74a7c6cd488563b7ae91bff1057bbebad926d3e03b4298d1b7ba549c5d1754db3c4a9bc25189bf0f19', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('8a7ee0ccd37a0e28999c0c40c4efb99ebe5b09594f56ba8d32a63c231b9d6e0dcd763cc8fc6236b8f8fd8c4eb036425d05aa6acc7f67477c1e6d161978eaeb51', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('ad65f355f3e29977454e43648e2dcfc70d23e4b87eadd2f82e40d4d384fc965cc14951c81c33ab21ed16c55c23816371d053d9a1dafafbfad90c1ac39e3704fe', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('49f93020e6143908ab9b7e81a9d56a17fbf2e07d3db675b64f0554d1cd941b46fb59926d0cb8ba603bec90a9683e4b0e821d9a81dd1750dfc9de2f65dc80ecd5', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('598f3d2743d6610b4df42a16063095f19945199508d8c206acb3f2ee1aee5a0c23b0e9c5bcdd984d0b38a1db0af586b6f7cdc56c8e9b6cd0b0b3ec2d394af7a2', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4c485fdacc68a780eaa5afd322a9f3930caa0ca00484d701f2967f2e16aba2e8944e9d89e145bc4ebd75c28bf1be2f615015c898cf70c6b0769e28bb298cd4fe', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('4da36913749e64360eb1ce8e7cdf39bf6300776ec9290e0eb48ccac029c094ab50850cfaa0aec7dfffd2df3c814c2fa3067c8cdd60d5ccf53a726a2e70aae2fa', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('d6c6cb023850d2c183914a2aa6410a321b49bd0fb3bd106b7e5864fdbda371b716d07f1fe84f872a7fca7a90b12528eec54a6e1520f583d65b647b73a916e4a0', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('85cb50ee4a616ea80685969d0dc9e228eb22ae3462c576079b197417c8325915257e16222e92a52a6e3edf2f3f57e47a40b70ab42509c4504ed5f7d7d76578ea', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('237bd85c49c064ab3443571f86de2524d27c9f684334a1d753ef38a2189e1d9d822113ff2f3b0bb0c2fec3bf36288e7dcd3f1a7b63b3838c74a5e8c8fe3317f9', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('dbdcba4e31377a632ed65b85c4a004ca75ab3138ee34926c0d1b6b0d93da31ebcf0290536b589fe4211a3a229c6037acdcd29b6fc012f3f2f45ec1a9e5346184', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('2b6a3e5b1966dea44baac62478e30bedcd2a82ed5a18ef042f16dad95df8692af8af89fe2279c952ffaf7106fa5edcd6a469109f8b1d09df58c8cdbaf2997c9e', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('18242fd4aafa414575e9de0e89861bfef057675375cc040859c8aa745912527966e58ac90c87190fe5e851e7b23eed60575ea4614ec2c1a54ea6a676532ed923', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('42158557d83d10ecca2b65fd062778ab6e75e5dd78138cb0b5e15beb57fc8a826f40ef166817ed83fca097db64666333d83e1a94b74cd78ae5637855bd5a722e', None, None, None, 1, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('e98dff0540c74045656c8a0451628b2de8b36dc6ca80c04eabb31c9739dbe940d1fa9ff8b17c8bad2f4527633a5911c4a23c015e0eff3a39a2f65e9aab7980a4', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('660f3dad33b0b4089cea11061bc25edb3220d0a587502eb20ef9182f1f03738f2bf0576b77f1df9f18310bc4fca7426c8106e217c1123bd1ce9cf94e62cc401e', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('5e99f23fc26e43bc60a7c874d07ee27d4d905db0e92bc329e5c117a3d9eec3f4883bb1d44d563541c9ce86ce58ea1256c60a31dcd1d91b923949aae484b4d9c3', None, None, None, 3, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('b2d6acc029aa167909b8d10b840b3e3a90348def671b912c641811bd09ceaa3bd760b924a6a45b40a7ed49f3865c367d0d83419ea03a038bb235db13b2c35526', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('3ccf751b152316b0099b918ea704de78110dc9dcf00b81f5d9f9999f04c16aaaec4f5577b4338ccd9418c3412ce97904b9bff18ecf07aa9523121a2a53fa1be4', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('f1e08f7e5f5813c9fc51037bc1a3fe56981d53a5e540139cc4861bb6a5644b4c05ea219d603a80bc0213a3f2a6b98c1f9627e10628b3e048511172563704b91a', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('a602b07157b0024dedc0d584b8a182220122f0d3ab686cfcbb7d792adad3d11d0e4eaf57f479d64dfc085c2f591c8d3d0fadcdc4ab81d99e2b79652f0a3f243c', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('ca2107567bf31d485313b836e6bc56ed19b72aa85745846a70346fb75994db71d7fbe159120822378f7ff1a9d4b25dfe01a1b77d60c3fe82115c3c503d614fdb', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('e6cb76b7335fe82e9ea0761778412e476610b730f476081cbeba4c9f1245def1a0dd21a72764af806caf8a8d295c7e8a7cc91f04b29352a2be2687ddd2b22a60', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('884a7f6b9de190109c1034ece200c8d595a6392fa0216474b7d40f67ef94de1abc98a31075a46730e2ea573a9b6c4e854b2b528d7dc7ba0c67a733cc5c948f7b', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('33d2bb1538f5ea59f28e14f3e76b4c758124993598e8139ee8ef6ef90b199755fe3946651989c72e3cef489569ebf1e7b9f3f9e004831e4408e44fdf1d9734cf', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('115349f24b3342680e086bf68e0b8bfde3379c5645d1f1695455686f0f5708a7005a49e22311f1dfcccfb078f3796a4c5cf45c8359bf1f58dfd060189b705568', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# Insert values: ('6f0bfd99cb1698e068395d05b4983c5ee8e85ad52fed694da087d0fe5bcd0a70c90c3076a4e8122bbc6b5ca0454a979345c2d6be1fe78ff4da3d679a40e74e95', None, None, None, 2, None)
# Insert query: INSERT INTO chicago_dmv.Crash (CRASH_UNIT_ID, CRASH_ID, PERSON_ID, VEHICLE_ID, NUM_UNITS, TOTAL_INJURIES) VALUES (%s, %s, %s, %s, %s, %s);
# ...
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254359', '06284bfb731899cbab79f94408484c38726c01a69c4d2e60355e41b3b1c9372697eae8071623e5a3ba0f84fdae12069db995bf02dc7c36c19a80fb257fa7e368', '2021-12-29T12:55:00.000', 'DRIVER', 1190670.0, 'M', 27.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254360', '06284bfb731899cbab79f94408484c38726c01a69c4d2e60355e41b3b1c9372697eae8071623e5a3ba0f84fdae12069db995bf02dc7c36c19a80fb257fa7e368', '2021-12-29T12:55:00.000', 'DRIVER', 1190673.0, 'M', 40.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254346', '474b5f465523cbb7ed6ce16177c9abab8843db07eba8b77f2312a65fae3bdaedd636fa97773f6eacfdf0bee72d02b974ade8601dfc7404e8d33252ff49684f92', '2021-12-29T12:55:00.000', 'DRIVER', 1190651.0, 'M', 49.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254347', '99b473536d72a1585cde332c61e8ca768831e8a7541cb101822bb135bf3a76f19defd2ae649e08f7ceded00e175ec4e8a31767c3b6d0b2396036e68747ac508b', '2021-12-29T12:55:00.000', 'DRIVER', 1190659.0, 'M', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254348', '99b473536d72a1585cde332c61e8ca768831e8a7541cb101822bb135bf3a76f19defd2ae649e08f7ceded00e175ec4e8a31767c3b6d0b2396036e68747ac508b', '2021-12-29T12:55:00.000', 'DRIVER', 1190665.0, 'F', 61.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1255220', '331f7b28f554812dbd17b65d43851c241cb8cdb2a6b6b1d1ced6332a650a9ffea7eccbd14a1501703e7a0282717dea998f0b668c9e481d8aa59ae00d89c36397', '2021-12-29T12:50:00.000', 'DRIVER', 1191494.0, 'M', 46.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1255221', '331f7b28f554812dbd17b65d43851c241cb8cdb2a6b6b1d1ced6332a650a9ffea7eccbd14a1501703e7a0282717dea998f0b668c9e481d8aa59ae00d89c36397', '2021-12-29T12:50:00.000', 'DRIVER', 1191498.0, 'M', 27.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254335', 'f2e226e4266a96ad2012e281217ebe85378b82c51e9215a607790084a0a78ec22101a27f8281b5f2f4557b3796773dd48e5fa8f0b2f04aaf4f6981e25c28b103', '2021-12-29T12:50:00.000', 'DRIVER', 1190658.0, 'F', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254336', 'f2e226e4266a96ad2012e281217ebe85378b82c51e9215a607790084a0a78ec22101a27f8281b5f2f4557b3796773dd48e5fa8f0b2f04aaf4f6981e25c28b103', '2021-12-29T12:50:00.000', 'DRIVER', 1190663.0, 'M', 23.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254305', '27d25268a762cc6aaa956ed35c1d4f936c379ab9f2b60c0f4a1b1ddb3ae184f5f418766e9f8bd48d613942b3d97088b92fd9a9ddc2ced9985d9e0fc95d5c9549', '2021-12-29T12:36:00.000', 'DRIVER', 1190617.0, 'M', 31.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254306', '27d25268a762cc6aaa956ed35c1d4f936c379ab9f2b60c0f4a1b1ddb3ae184f5f418766e9f8bd48d613942b3d97088b92fd9a9ddc2ced9985d9e0fc95d5c9549', '2021-12-29T12:36:00.000', 'DRIVER', 1190632.0, 'M', 37.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254672', '1cfab00d22966f04ee5d047ae847bc8d82ad2c14a62cb9e4eb6f4e8d21fd1768d9647a8897a3eca70e1b0b59d27d8cb230e91a64cdf21ccd7f2c73a375a88618', '2021-12-29T12:30:00.000', 'DRIVER', 1190974.0, 'M', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254673', '1cfab00d22966f04ee5d047ae847bc8d82ad2c14a62cb9e4eb6f4e8d21fd1768d9647a8897a3eca70e1b0b59d27d8cb230e91a64cdf21ccd7f2c73a375a88618', '2021-12-29T12:30:00.000', 'DRIVER', 1190978.0, 'F', 23.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254434', 'd6bf3002f7f4642b2ca2c53df8a1f3756681cf6d22c70aac8d37e551e1ac3604fd598d3494b12f2ecaea130349ca38922c002f57cae396e6e4cee39525ae0341', '2021-12-29T12:30:00.000', 'DRIVER', 1190737.0, 'M', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254311', '3bba2910bb4ba10b67ef50a155e1d51067909dafbe91d873f518414a55966657921a7d7ba863f9c482fa814b477cded01fade909f5a9eb4b212ee3f1ed9a800d', '2021-12-29T12:24:00.000', 'DRIVER', 1190620.0, 'F', 29.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254312', '3bba2910bb4ba10b67ef50a155e1d51067909dafbe91d873f518414a55966657921a7d7ba863f9c482fa814b477cded01fade909f5a9eb4b212ee3f1ed9a800d', '2021-12-29T12:24:00.000', 'DRIVER', 1190628.0, 'F', 36.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('P280433', '3bba2910bb4ba10b67ef50a155e1d51067909dafbe91d873f518414a55966657921a7d7ba863f9c482fa814b477cded01fade909f5a9eb4b212ee3f1ed9a800d', '2021-12-29T12:24:00.000', 'PASSENGER', 1190628.0, 'F', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('P280434', '3bba2910bb4ba10b67ef50a155e1d51067909dafbe91d873f518414a55966657921a7d7ba863f9c482fa814b477cded01fade909f5a9eb4b212ee3f1ed9a800d', '2021-12-29T12:24:00.000', 'PASSENGER', 1190628.0, 'F', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('P280435', '3bba2910bb4ba10b67ef50a155e1d51067909dafbe91d873f518414a55966657921a7d7ba863f9c482fa814b477cded01fade909f5a9eb4b212ee3f1ed9a800d', '2021-12-29T12:24:00.000', 'PASSENGER', 1190628.0, 'F', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254307', '19232dc2d6a8bc21579a1cf992d9b734f4e428c57e01af29cc5fe895be22df0f220a280e47cf8d8097f92d042783e08b5462254a7ba6f151b882136cd1377836', '2021-12-29T12:17:00.000', 'DRIVER', 1190613.0, 'X', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254742', 'fb0efda8318355680397983d9fd708ec8f1d6b34a71981b9578122048ef337e6558a8c7e420064f7294d7a9adc72eef6d615c3eb50e6173a2ec6c56cbd6141a6', '2021-12-29T12:15:00.000', 'DRIVER', 1191041.0, 'M', 63.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254743', 'fb0efda8318355680397983d9fd708ec8f1d6b34a71981b9578122048ef337e6558a8c7e420064f7294d7a9adc72eef6d615c3eb50e6173a2ec6c56cbd6141a6', '2021-12-29T12:15:00.000', 'DRIVER', 1191042.0, 'F', 48.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254269', '038e36aeb372e7bf0d8d89cbea1debbb631bf09b9352d2e9ead3c6f006c76ae28fa1af5996149a78a2cdd761d0e3e7ec01a58ef244c4cf2ed6ac0a147c3e039b', '2021-12-29T12:13:00.000', 'DRIVER', 1190587.0, 'M', 48.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254270', '038e36aeb372e7bf0d8d89cbea1debbb631bf09b9352d2e9ead3c6f006c76ae28fa1af5996149a78a2cdd761d0e3e7ec01a58ef244c4cf2ed6ac0a147c3e039b', '2021-12-29T12:13:00.000', 'DRIVER', 1190593.0, 'M', 24.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254313', '9a71ef56cc6176f8f0e43412ef3b5cd884fb9677345232c3f715d76b67345585f4de55f1e4e0767b7a4c8b8eea2b52e0eaf10e0acceafdc6e08991e3fc146e34', '2021-12-29T12:13:00.000', 'DRIVER', 1190637.0, 'M', 57.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254282', '36554239390773cfedd5a0e63b5da4afc1ebfd8bc43802a04a500365a8a6e89b4664ced96c93e883026637fb79d7670d9a5c5a9036be7a50e7ec56ba7e8b2e8b', '2021-12-29T12:10:00.000', 'DRIVER', 1190595.0, 'M', 38.52454417952314)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254283', '36554239390773cfedd5a0e63b5da4afc1ebfd8bc43802a04a500365a8a6e89b4664ced96c93e883026637fb79d7670d9a5c5a9036be7a50e7ec56ba7e8b2e8b', '2021-12-29T12:10:00.000', 'DRIVER', 1190599.0, 'M', 37.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1258817', 'a4d70540ef233bf5a2d435eb18c223d401cdfc95fca25921b8f3e4684e8235beadbc18569c6e7c7551d1c2f1cefc65a37bc80b4c3934c7d137b685df8869da14', '2021-12-29T12:10:00.000', 'DRIVER', 1194903.0, 'F', 17.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1258818', 'a4d70540ef233bf5a2d435eb18c223d401cdfc95fca25921b8f3e4684e8235beadbc18569c6e7c7551d1c2f1cefc65a37bc80b4c3934c7d137b685df8869da14', '2021-12-29T12:10:00.000', 'DRIVER', 1194908.0, 'M', 37.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254271', '7ed03b2fb825e833296fc48ee26885fa51398706b16eaeef41f50ee991d667a37a1590873876991d476cef188b6216b7d4cd105452a6725ad3dc711f0d157e54', '2021-12-29T12:00:00.000', 'DRIVER', 1190586.0, 'F', 0.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254272', '7ed03b2fb825e833296fc48ee26885fa51398706b16eaeef41f50ee991d667a37a1590873876991d476cef188b6216b7d4cd105452a6725ad3dc711f0d157e54', '2021-12-29T12:00:00.000', 'DRIVER', 1190588.0, 'M', 34.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('P280425', '7ed03b2fb825e833296fc48ee26885fa51398706b16eaeef41f50ee991d667a37a1590873876991d476cef188b6216b7d4cd105452a6725ad3dc711f0d157e54', '2021-12-29T12:00:00.000', 'PASSENGER', 1190586.0, 'F', 21.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254276', 'b96fa466bfb6d4e5399f298fb9c995f991f8a2cb387c407c7b79cf204071f578a743e7501cddac8d9d3ea5a14c6cf1dd1710f17e491d17c625748f9e61bf8090', '2021-12-29T11:59:00.000', 'DRIVER', 1190589.0, 'F', 46.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254277', 'b96fa466bfb6d4e5399f298fb9c995f991f8a2cb387c407c7b79cf204071f578a743e7501cddac8d9d3ea5a14c6cf1dd1710f17e491d17c625748f9e61bf8090', '2021-12-29T11:59:00.000', 'DRIVER', 1190591.0, 'M', 63.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254329', '9f21abf39f31da38bee1cdbb501f072491054792a61be8192e726672546da0aeadc38272d7754ab85405c91aed785c2589601e9e09303428d64d7d0f722e79a0', '2021-12-29T11:58:00.000', 'DRIVER', 1190640.0, 'M', 39.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254299', '9aae9fd965fe2eeb41eb38c10b911fcc67fa73f59921f4def6ae1079dc09cc7055140547891a842fc5c1b55d19207a4fab305f9b492d9a08832010c7599040f9', '2021-12-29T11:55:00.000', 'DRIVER', 1190603.0, 'M', 67.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254300', '9aae9fd965fe2eeb41eb38c10b911fcc67fa73f59921f4def6ae1079dc09cc7055140547891a842fc5c1b55d19207a4fab305f9b492d9a08832010c7599040f9', '2021-12-29T11:55:00.000', 'PEDESTRIAN', 1191430.6063072227, 'M', 86.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('P280428', '9aae9fd965fe2eeb41eb38c10b911fcc67fa73f59921f4def6ae1079dc09cc7055140547891a842fc5c1b55d19207a4fab305f9b492d9a08832010c7599040f9', '2021-12-29T11:55:00.000', 'PASSENGER', 1190603.0, 'M', 63.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254297', '5792f36a2971a5979c494d16d811b74d977a8cb07f63e87f0acad8d82cc91feb2e9bea1ff9920c06376611a70659e692ffd6b615d59180d2fe3495d2dc03caec', '2021-12-29T11:52:00.000', 'DRIVER', 1190611.0, 'F', 46.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254298', '5792f36a2971a5979c494d16d811b74d977a8cb07f63e87f0acad8d82cc91feb2e9bea1ff9920c06376611a70659e692ffd6b615d59180d2fe3495d2dc03caec', '2021-12-29T11:52:00.000', 'DRIVER', 1190627.0, 'M', 48.0)
# Insert query: INSERT INTO chicago_dmv.Person (PERSON_ID, CRASH_ID, CRASH_DATE, PERSON_TYPE, VEHICLE_ID, PERSON_SEX, PERSON_AGE) VALUES (%s, %s, %s, %s, %s, %s, %s);
# Insert values: ('O1254290', '5ba4cf077aab55de2858904ed5bf5ac03afb71cdc8c428f6d11803ae93dd87ba11c2c1e3aaf72ddb9c2b7b7bb64d36a1c554e37dd48e56ba4fcfc4cb4e229443', '2021-12-29T11:45:00.000', 'DRIVER', 1190601.0, 'M', 66.0)

# %% [markdown]
# > ⚠️
# > There's future warnings
